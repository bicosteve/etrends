# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# %%
data_frame = pd.read_csv('../dataset/cat_2_dataset.csv')

# %%
#data_frame.head()

# %%
#data_frame.columns

# %%
X = data_frame[['Sleep Hours']]

# %%
y = data_frame['Exam Scores']

# %%
# Splitting the dataset for training and testing
X_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=20)

# %%
# Instantiate linear model
linear_model = LinearRegression()

# %%
# Training the model -- Q ---> (i)
linear_model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# Print coeffient and intercept
coeffienct = linear_model.coef_
intercept = linear_model.intercept_

print(f'Coeffient is {coeffienct}')
print(f'Intercept is {intercept}')
# Out:
# Coeffient is [-5.5]
# Intercept is 82.5

# %%
data = [[5]]
data = np.array(data)
predictions = linear_model.predict(data.reshape(1,-1))
print(predictions)
# Out:
# [55.]
# /opt/homebrew/anaconda3/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
