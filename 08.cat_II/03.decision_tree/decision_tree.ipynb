# %%
import pandas as pd
import numpy as np 
from sklearn.preprocessing import LabelEncoder
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split

# %%
data_frame = pd.read_csv('../dataset/cat_2_dataset.csv')

# %%
data_frame.columns
# Out:
# Index(['ID', 'Study Hours', 'Sleep Hours', 'Attendance',
#        'Assignment Completed', 'Internet Usage (hrs)', 'Exam Scores'],
#       dtype='object')

# %%
X = data_frame[['Study Hours', 'Sleep Hours', 'Attendance','Assignment Completed', 'Internet Usage (hrs)']]

# %%
# Getting the values of y
# You can use labelEncoder to transform the data into numeric or just make it have 1 and 0 according to
# pass status
y = []
for score in data_frame['Exam Scores']:
    if score < 50:
        y.append(1)
    else:
        y.append(0)
print(y)
# Out:
# [1, 0, 0, 0, 1, 0, 0, 1, 0, 0]

# %%
model = DecisionTreeClassifier()

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.3, random_state=10)

# %%
# Training the model
model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
# Making predictions with x_test
prediction = model.predict(X_test)

# %%
# Evaluate Prediction
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
accuracy = accuracy_score(y_test, prediction)
report = classification_report(y_test, prediction)
confusion_mtrx = confusion_matrix(y_test, prediction)

print(f"Model accuracy {accuracy}")
print(f"Model classification report {report}")
print(f"Model confusion matrix {confusion_mtrx}")
# Out:
# Model accuracy 1.0
# Model classification report               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         3
#
#     accuracy                           1.00         3
#    macro avg       1.00      1.00      1.00         3
# weighted avg       1.00      1.00      1.00         3
#
# Model confusion matrix [[3]]
# /opt/homebrew/anaconda3/lib/python3.12/site-packages/sklearn/metrics/_classification.py:409: UserWarning: A single label was found in 'y_true' and 'y_pred'. For the confusion matrix to have the correct shape, use the 'labels' parameter to pass all known labels.
#   warnings.warn(

# %%
# Find prediction for provided data
data = [5,6,85,4,3]
data = np.array(data)

new_prediction = model.predict(data.reshape(1,-1))
print("New prediction is",new_prediction)
# Out:
# New prediction is [0]
# /opt/homebrew/anaconda3/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
